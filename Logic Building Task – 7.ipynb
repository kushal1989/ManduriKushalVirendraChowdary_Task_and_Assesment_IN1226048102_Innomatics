# %%
class SmartLight:
    def __init__(self, name):
        self.name = name
        self.status = "OFF"

    def turn_on(self):
        self.status = "ON"

    def turn_off(self):
        self.status = "OFF"

    def display(self):
        print(f"{self.name} is {self.status}")

light = SmartLight("Bedroom Light")
light.turn_on()
light.display()
# Out:
# Bedroom Light is ON

# %%
class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.department)

emp = Employee("Kushal", "734325", "Data Science")
emp.display()
# Out:
# Employee ID Card
# Name: Kushal
# ID: 734325
# Department: Data Science

# %%
class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)

c = Contact("Kushal", "9876543210")
c.display()
# Out:
# Contact Saved
# Name: Kushal
# Phone: 9876543210

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def display(self):
        print(f"Product: {self.name}")
        print(f"Price: ₹{self.price}")

p = Product("Bluetooth Earphones", 2499)
p.display()
# Out:
# Product: Bluetooth Earphones
# Price: ₹2499

# %%
class Movie:
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating

    def display(self):
        print(f"Movie: {self.name}")
        print(f"Rating: {self.rating} / 5")

m = Movie("RRR", 4.8)
m.display()
# Out:
# Movie: RRR
# Rating: 4.8 / 5

# %%
class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display(self):
        print("Delivery Details")
        print("Customer:", self.customer_name)
        print("Address:", self.address)

d = Delivery("Kushal", "Hyderabad")
d.display()
# Out:
# Delivery Details
# Customer: Kushal
# Address: Hyderabad
